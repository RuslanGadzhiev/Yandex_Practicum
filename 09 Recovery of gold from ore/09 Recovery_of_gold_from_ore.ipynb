# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Ознакомление-с-данными" data-toc-modified-id="Ознакомление-с-данными-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Ознакомление с данными</a></span><ul class="toc-item"><li><span><a href="#Вывод-после-изучения-полученных-данных" data-toc-modified-id="Вывод-после-изучения-полученных-данных-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Вывод после изучения полученных данных</a></span></li></ul></li><li><span><a href="#Расчёт-эффективности-добычи-золота" data-toc-modified-id="Расчёт-эффективности-добычи-золота-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Расчёт эффективности добычи золота</a></span><ul class="toc-item"><li><span><a href="#Вывод-об-эффективности-расчета-средней-квадратичной-ошибки(МАЕ)" data-toc-modified-id="Вывод-об-эффективности-расчета-средней-квадратичной-ошибки(МАЕ)-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Вывод об эффективности расчета средней квадратичной ошибки(МАЕ)</a></span></li></ul></li><li><span><a href="#Анализ-признаков,-недоступных-в-тестовой-выборке" data-toc-modified-id="Анализ-признаков,-недоступных-в-тестовой-выборке-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Анализ признаков, недоступных в тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Вывод-по-отсутствующим-признакам" data-toc-modified-id="Вывод-по-отсутствующим-признакам-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Вывод по отсутствующим признакам</a></span></li></ul></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Выводы-после-предобработки" data-toc-modified-id="Выводы-после-предобработки-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Выводы после предобработки</a></span></li></ul></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Анализ данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-концентрации-металлов-на-различных-этапах-очистки" data-toc-modified-id="Анализ-концентрации-металлов-на-различных-этапах-очистки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ концентрации металлов на различных этапах очистки</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Сравнение-распределения-гранул-сырья-на-обучающей-и-тестовой-выборках" data-toc-modified-id="Сравнение-распределения-гранул-сырья-на-обучающей-и-тестовой-выборках-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Сравнение распределения гранул сырья на обучающей и тестовой выборках</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях-очистки" data-toc-modified-id="Анализ-суммарной-концентрации-всех-веществ-на-разных-стадиях-очистки-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Анализ суммарной концентрации всех веществ на разных стадиях очистки</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Удаление-аномальных-значений-из-обучающей-и-тестовой-выборок" data-toc-modified-id="Удаление-аномальных-значений-из-обучающей-и-тестовой-выборок-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Удаление аномальных значений из обучающей и тестовой выборок</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Модель" data-toc-modified-id="Модель-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Модель</a></span><ul class="toc-item"><li><span><a href="#Метрика-качества" data-toc-modified-id="Метрика-качества-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Метрика качества</a></span></li><li><span><a href="#Расчет-метрики-качества-для-выбранных-моделей" data-toc-modified-id="Расчет-метрики-качества-для-выбранных-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Расчет метрики качества для выбранных моделей</a></span></li><li><span><a href="#LinearRegression" data-toc-modified-id="LinearRegression-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>LinearRegression</a></span></li><li><span><a href="#Поиск-оптимальных-параметров-для-моделей-случайного-дерева-и-решающего-леса" data-toc-modified-id="Поиск-оптимальных-параметров-для-моделей-случайного-дерева-и-решающего-леса-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Поиск оптимальных параметров для моделей случайного дерева и решающего леса</a></span></li><li><span><a href="#DecisionTreeRegressor" data-toc-modified-id="DecisionTreeRegressor-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>DecisionTreeRegressor</a></span></li><li><span><a href="#RandomForestRegressor" data-toc-modified-id="RandomForestRegressor-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>RandomForestRegressor</a></span><ul class="toc-item"><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-лучшей-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-лучшей-модели-на-тестовой-выборке-3.7"><span class="toc-item-num">3.7&nbsp;&nbsp;</span>Проверка лучшей модели на тестовой выборке</a></span></li><li><span><a href="#Проверка-на-адекватность" data-toc-modified-id="Проверка-на-адекватность-3.8"><span class="toc-item-num">3.8&nbsp;&nbsp;</span>Проверка на адекватность</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.9"><span class="toc-item-num">3.9&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Восстановление золота из руды

# %% [markdown]
# Подготовьте прототип модели машинного обучения для «Цифры». Компания разрабатывает решения для эффективной работы промышленных предприятий.
#
# Модель должна предсказать коэффициент восстановления золота из золотосодержащей руды. Используйте данные с параметрами добычи и очистки.
#
# Модель поможет оптимизировать производство, чтобы не запускать предприятие с убыточными характеристиками.
#
# Вам нужно:
#
# 1. Подготовить данные;
# 2. Провести исследовательский анализ данных;
# 3. Построить и обучить модель.
#
# Чтобы выполнить проект, обращайтесь к библиотекам *pandas*, *matplotlib* и *sklearn.* Вам поможет их документация.
#
# В нашем распоряжении сырые данные.
#
# ***Описание данных***
# **Технологический процесс**
# `Rougher feed` — исходное сырье
# `Rougher additions` — флотационные реагенты: Xanthate, Sulphate, Depressant
# `Rougher process`  — флотация
# `Rougher tails` — отвальные хвосты
# `Float banks` — флотационная установка
# `Cleaner process` — очистка
# `Rougher Au` — черновой концентрат золота
# `Final Au` — финальный концентрат золота
# **Параметры этапов**
# `air amount` — объём воздуха
# `fluid levels` — уровень жидкости
# `feed size` — размер гранул сырья
# `feed rate` — скорость подачи
# **Наименование признаков**
# `rougher` — флотация
# `primary_cleaner` — первичная очистка
# `secondary_cleaner` — вторичная очистка
# `final` — финальные характеристики
# Возможные значения для блока:
# `input` — параметры сырья
# `output` — параметры продукта
# `state` — параметры, характеризующие текущее состояние этапа
# `calculation` — расчётные характеристики

# %% [markdown]
# ## Подготовка данных

# %%
# Импорт библиотек.
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings

# Импорт модулей IPython и numpy.
from IPython.core.display import display, HTML
from IPython.display import display_html
from IPython.display import display, Math, Latex

# Импорт моделей, метрик и модулей sklearn.
from sklearn.ensemble import RandomForestRegressor
from sklearn.dummy import DummyRegressor
from sklearn.impute import KNNImputer
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score,cross_validate,RandomizedSearchCV
from sklearn.metrics import accuracy_score, mean_squared_error,mean_absolute_error, make_scorer
from sklearn.neighbors import KNeighborsRegressor
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeRegressor

# %%
try:
    gold_full = pd.read_csv('gold_recovery_full_new.csv',sep=',')
    gold_train = pd.read_csv('gold_recovery_train_new.csv',sep=',')
    gold_test = pd.read_csv('gold_recovery_test_new.csv',sep=',')
    pd.set_option('display.max_columns', None)
    pd.options.mode.chained_assignment = None
except:
    gold_full = pd.read_csv('/datasets/gold_recovery_full_new.csv',sep=',')
    gold_train = pd.read_csv('/datasets/gold_recovery_train_new.csv',sep=',')
    gold_test = pd.read_csv('/datasets/gold_recovery_test_new.csv',sep=',')
    pd.set_option('display.max_columns', None)
    pd.options.mode.chained_assignment = None

# %% [markdown]
# ### Ознакомление с данными

# %%
def info_row(df):
    '''
        Input: df - таблица pd.DataFrame.
        Output: None.
        Description: Функция первичного знакомства с данными.

    '''
    display(df.head(10))
    print('Общая информация:')
    display(df.info())
    print('Общая статистика:')
    display(df.describe())
    print('Дубликаты:')
    display(df.duplicated().sum())
    print('Пропуски:')
    for col in df.columns:
        pct_missing = np.mean(df[col].isna())
        print('{} - {}%'.format(col, round(pct_missing*100,2)))

# %%
info_row(gold_full)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
# 5  2016-01-15 05:00:00                     6.482968
# 6  2016-01-15 06:00:00                     6.533849
# 7  2016-01-15 07:00:00                     6.130823
# 8  2016-01-15 08:00:00                     5.834140
# 9  2016-01-15 09:00:00                     5.687063
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
# ...

# %%
info_row(gold_train)
# Out:
#                   date  final.output.concentrate_ag  \
# 0  2016-01-15 00:00:00                     6.055403
# 1  2016-01-15 01:00:00                     6.029369
# 2  2016-01-15 02:00:00                     6.055926
# 3  2016-01-15 03:00:00                     6.047977
# 4  2016-01-15 04:00:00                     6.148599
# 5  2016-01-15 05:00:00                     6.482968
# 6  2016-01-15 06:00:00                     6.533849
# 7  2016-01-15 07:00:00                     6.130823
# 8  2016-01-15 08:00:00                     5.834140
# 9  2016-01-15 09:00:00                     5.687063
#
#    final.output.concentrate_pb  final.output.concentrate_sol  \
# 0                     9.889648                      5.507324
# 1                     9.968944                      5.257781
# 2                    10.213995                      5.383759
# 3                     9.977019                      4.858634
# 4                    10.142511                      4.939416
# ...

# %%
info_row(gold_test)
# Out:
#                   date  primary_cleaner.input.sulfate  \
# 0  2016-09-01 00:59:59                     210.800909
# 1  2016-09-01 01:59:59                     215.392455
# 2  2016-09-01 02:59:59                     215.259946
# 3  2016-09-01 03:59:59                     215.336236
# 4  2016-09-01 04:59:59                     199.099327
# 5  2016-09-01 05:59:59                     168.485085
# 6  2016-09-01 06:59:59                     144.133440
# 7  2016-09-01 07:59:59                     133.513396
# 8  2016-09-01 08:59:59                     133.735356
# 9  2016-09-01 09:59:59                     126.961069
#
#    primary_cleaner.input.depressant  primary_cleaner.input.feed_size  \
# 0                         14.993118                         8.080000
# 1                         14.987471                         8.080000
# 2                         12.884934                         7.786667
# 3                         12.006805                         7.640000
# ...

# %%
# %%time
plt.figure(figsize=(40, 50), dpi= 30)
heatmap = sns.heatmap(gold_full.corr(), vmin=-1, vmax=1, annot=True,cmap='BrBG',
                      cbar_kws= {'orientation': 'horizontal'},fmt='.1g') 
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':30}, pad=12);

# Посмотрим на корреляцию с помощью heatmap.
# Более сильная корреляция на обоих концах спектра проявляется 
# в виде темных (насыщенных) ячеек, слабая – в виде светлых ячеек.
# Out:
# Wall time: 3.55 s
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
def cor_del_find(df,threshold):
    '''
        Input: df - таблица pd.DataFrame, threshold - вещественное число float.
        Output: col_corr_all, col_corr_del.
        Description: Функция анализирует корреляцию признаков, выбирает все с очень высокой корреляцией >= 0,9(threshold)
                     и на выход создает два списка. 
                     col_corr_all - собраны все уникальные столбцы с высокой корреляцией;
                     col_corr_del - каждый первый из взаимокоррелируемых

    '''
    col_corr_del = []
    col_corr_all = []
    corr_matrix = df.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if  (corr_matrix.iloc[i, j] >= threshold):
                if (corr_matrix.columns[j],corr_matrix.columns[i] not in col_corr_all):
                    col_name_i = corr_matrix.columns[i]
                    col_name_j = corr_matrix.columns[j]
                    if col_name_i not in col_corr_all:
                        col_corr_all.append(col_name_i)
                        if col_name_j not in col_corr_all:
                            col_corr_all.append(col_name_j)
                if corr_matrix.columns[j] not in col_corr_del:
                    col_name = corr_matrix.columns[i]
                    col_corr_del.append(col_name)

    return col_corr_all, col_corr_del

# %%
corr_all_high,columns_to_del = cor_del_find(gold_full,0.9)

# %%
# %%time

high_corr_columns = gold_full.loc[:, corr_all_high].copy(deep=True)

plt.figure(figsize=(20, 20), dpi=50)
heatmap = sns.heatmap(high_corr_columns.corr(), vmin=-1, vmax=1, annot=True,cmap='BrBG',
                      fmt='.2g') 
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':20}, pad=12);
# Out:
# Wall time: 388 ms
# Text(0.5, 1.0, 'Correlation Heatmap')

# %%
def corr_del(df):
    '''
        Input: df - таблица pd.DataFrame.
        Output: None.
        Description: Функция удаляет все столбцы, 
                     соответствующие списку columns_to_del.
    '''

    for column in df.columns:
        if column in columns_to_del:
            df.drop(column, axis=1,inplace=True)

# %% [markdown]
# #### Вывод после изучения полученных данных

# %% [markdown]
# *Предоставленные в работу данные, состоят из трех выборок:*
# * `gold_recovery_full_new` - *исходные данные;*
# * `gold_recovery_train_new` - *обучающая выборка;*
# * `gold_recovery_test_new` - *тестовая выборка.*
#
# *Выборки представляют собой выгруженные сырые данные процесса технологической обработки золотоносной руды.*
# * *Параметры сырья, подающегося во флотационную установку на различных этапах очистки(флотация, первичная и вторичная очистки), а так же полученные после обогащения черновой концентрат и «отвальные хвосты». - `признаки`*
# * *Параметры, оценивающие эффективность обогащения чернового и финального концентрата(`rougher.output.recovery`,`final.output.recovery`). - `целевые признаки`.*
# * *В тестовой выборке отсутствует 34 колонки(`включая оба целевых признака`), доступные в исходных данных и обучающей выборке. Скорее всего это связано с тем, что некоторые параметры недоступны, потому что замеряются и/или рассчитываются значительно позже.*
# * *В данных наблюдается небольшое количество пропусков, но так как данные индексируются датой и временем получения информации (признак `date`). Соседние по времени параметры часто похожи.*
#
# ***План на предобработку:***
# * *Проанализировать недоступные в тестовой выборке признаки;*
# * *Избавиться от пропусков, путем заполнения, методом `ffill`;*
# * *Перевести признак `date` в индексы, для заполнения пропущенных данных, в дальнейшем;*
# * *Удалить из обучающей выборки отсутствующие в тестовой признаки(исключая целевые);*
# * *Восстановить целевые признаки в тестовой выборке из исходных данных(соответствующих индексу `date`).*

# %% [markdown]
# ### Расчёт эффективности добычи золота

# %% [markdown]
# •   ***Recovery*** - *эффективность обогащения;*
# •	***C*** — *доля золота в концентрате после флотации/очистки;*
# •	***F*** — *доля золота в сырье/концентрате до флотации/очистки;*
# •	***T*** — *доля золота в отвальных хвостах после флотации/очистки.*
#
# *Эффективность обогащения расчитывается по формуле:*
#
#
# $$Recovery = \frac{C*\left ( F - T \right )}{F*\left ( C - T \right )}*100\%$$
#
# *Проверим правильно ли рассчитана эффективность обогащения. Вычислим её на обучающей выборке для признака `rougher.output.recovery`. Найдем MAE (среднюю абсолютную ошибку) между нашими расчётами и значением признака.*

# %%
gold_train_calc = gold_train.copy(deep=True)

# %%
def calc_recovery(df,color):
    '''
        Input: df - таблица pd.DataFrame, color - цвет вывода.
        Output: None.
        Description: Функция расчета средней абсолютной ошибки, 
                     для проверки правильности расчетов эффективности обогащения.
    '''

    df.dropna(inplace=True)
    C = df['rougher.output.concentrate_au']
    F = df['rougher.input.feed_au'] 
    T = df['rougher.output.tail_au']
    df['rougher.output.recovery_calc'] = ((C*(F-T))/(F*(C-T)))*100
    mae = mean_absolute_error(df['rougher.output.recovery'],df['rougher.output.recovery_calc'])
    df.drop('rougher.output.recovery_calc', axis=1,inplace=True)
    display(HTML(f"<font color={color}> Cредняя квадратичная ошибка (MAE): {mae} </font>"))
    return mae

# %%
mae_calc = calc_recovery(gold_train_calc,'blue')
# Out:
# <font color=blue> Cредняя квадратичная ошибка (MAE): 9.82970122149377e-15 </font>

# %% [markdown]
# #### Вывод об эффективности расчета средней квадратичной ошибки(МАЕ)

# %% [markdown]
# *Значение `MAE` крайне мало, а значит эффективность обогащения рассчитана правильно.*

# %% [markdown]
# ### Анализ признаков, недоступных в тестовой выборке

# %%
columns_empty_test = []
count = 0
for column in gold_full.columns:
    if column not in gold_test.columns:
        count +=1
        columns_empty_test.append(column)
        print(column)
# Out:
# final.output.concentrate_ag
# final.output.concentrate_pb
# final.output.concentrate_sol
# final.output.concentrate_au
# final.output.recovery
# final.output.tail_ag
# final.output.tail_pb
# final.output.tail_sol
# final.output.tail_au
# primary_cleaner.output.concentrate_ag
# primary_cleaner.output.concentrate_pb
# primary_cleaner.output.concentrate_sol
# primary_cleaner.output.concentrate_au
# primary_cleaner.output.tail_ag
# primary_cleaner.output.tail_pb
# primary_cleaner.output.tail_sol
# primary_cleaner.output.tail_au
# rougher.calculation.sulfate_to_au_concentrate
# rougher.calculation.floatbank10_sulfate_to_au_feed
# rougher.calculation.floatbank11_sulfate_to_au_feed
# rougher.calculation.au_pb_ratio
# rougher.output.concentrate_ag
# rougher.output.concentrate_pb
# rougher.output.concentrate_sol
# rougher.output.concentrate_au
# rougher.output.recovery
# rougher.output.tail_ag
# rougher.output.tail_pb
# rougher.output.tail_sol
# rougher.output.tail_au
# ...

# %% [markdown]
# #### Вывод по отсутствующим признакам

# %% [markdown]
# *В тестовой выборке отсутствуют выходные параметры продукта,а так же данные о количестве веществ в отвальных хвостах для этапов флоатации, первичной и вторичной очистки. Среди них так же отсутствуют, необходимые нам целевые признаки(`rougher.output.recovery`,`final.output.recovery`).*

# %% [markdown]
# ### Предобработка данных

# %%
def preprocessing(df):
    df.fillna(method='ffill',axis=0,inplace=True)
    df = df.set_index('date',inplace=True)

# %%
preprocessing(gold_full)
preprocessing(gold_train)
preprocessing(gold_test)

# %%
calc_recovery(gold_train,'blue')
# Out:
# <font color=blue> Cредняя квадратичная ошибка (MAE): 9.73512347450521e-15 </font>
# 9.73512347450521e-15

# %% [markdown]
# *Заметим, что после обработки, средняя квадратичная ошибка уменьшилась.*

# %%
columns_empty_test.remove('final.output.recovery')
columns_empty_test.remove('rougher.output.recovery')
gold_train = gold_train.drop(columns=columns_empty_test,axis=1)

# %%
gold_test['rougher.output.recovery'] = gold_full['rougher.output.recovery'][gold_test.index]
gold_test['final.output.recovery'] = gold_full['final.output.recovery'][gold_test.index]

# %%
corr_del(gold_full)
corr_del(gold_train)
corr_del(gold_test)

# %%
print(gold_full.shape)
print(gold_train.shape)
print(gold_test.shape)
# Out:
# (19439, 72)
# (14149, 42)
# (5290, 42)

# %% [markdown]
# ### Выводы после предобработки

# %% [markdown]
# *План по предобработке полученных данных, выполнен в полной мере.
# На выходе мы имеем подготовленные обучающую и тестовые выборки с одинаковым количеством признаков, а так же не имеющих пропусков данных.*

# %% [markdown]
# ## Анализ данных

# %% [markdown]
# ### Анализ концентрации металлов на различных этапах очистки

# %%
au_concentrate = gold_full[['rougher.input.feed_au','rougher.output.concentrate_au',
                            'primary_cleaner.output.concentrate_au','final.output.concentrate_au']]
ag_concentrate = gold_full[['rougher.input.feed_ag','rougher.output.concentrate_ag',
                            'primary_cleaner.output.concentrate_ag','final.output.concentrate_ag']]
pb_concentrate = gold_full[['rougher.input.feed_pb','rougher.output.concentrate_pb',
                            'primary_cleaner.output.concentrate_pb','final.output.concentrate_pb']]
# Создадим выборки по концентрациям каждого металла на всех этапах очистки.

# %%
columns_name = ['Исходное сырье','Флотация','Первичная очистка', 'Вторичная очистка']

# %%
def met_con(concentrate,metal):
    """Функция выводит столбчатые диаграммы концентрации, подаваемых в аргумент веществ."""
   
    concentrate.columns = columns_name

    sns.set_theme(style="whitegrid")
    plots = sns.catplot( data=concentrate, kind='bar', ci = 0,palette="dark", alpha=0.6, height=6)
    
    
    plt.xlabel("Этапы очистки", fontsize=15)
    plt.title(f'Изменение концентрации {metal}', fontsize=20)
    plt.xticks(rotation=90)
    plt.show()
    
def substance_proportion(df,metal):
    """Функция выводит круговые диаграммы концентрации, подаваемых в аргумент веществ."""
    df_med = df.median(axis=0) 
    df_med.plot(kind='pie', figsize=(9, 9), autopct='%.2f%%',subplots=True)
    ax = plt.gca()
    ax.set_ylabel('')
    ax.set_title(f'Изменение концентрации {metal}',fontsize=15)
    plt.show()

# %%
met_con(au_concentrate, 'золота')
substance_proportion(au_concentrate,'золота')

# %%
met_con(ag_concentrate, 'серебра')
substance_proportion(ag_concentrate,'серебра')

# %%
met_con(pb_concentrate, 'свинца')
substance_proportion(pb_concentrate,'свинца')

# %% [markdown]
# #### Вывод

# %% [markdown]
# * *Концентрация золота, в процессе обработки увеличивается с 8% до 42%*
# * *Концентрация серебра, в процессе обработки уменьшается с 25% до 15%*
# * *Концентрация свинца, в процессе обработки увеличилась с 11% до 32% (значительно после флотации)*
#
# *На выходе получается металл лишь на 42% состоящий из золота, хотя благодаря данному процессу удалось увеличить концентрацию искомого драгоценного металла на 34%.*

# %% [markdown]
# ### Сравнение распределения гранул сырья на обучающей и тестовой выборках

# %%
def compare_granules(train,test):
    '''
        Input: train,test - таблицы pd.DataFrame.
        Output: None.
        Description: Функция выводит гистограммы, подаваемых в аргумент данных, 
                     а так же сравнивает их средний размер, дисперсию и мажквартильный размах.

    '''
    
    fig = plt.figure(figsize=(15, 6))

    ax1 = plt.subplot(1, 2, 1)
    ax1 = sns.histplot(train,  kde=True,bins=60,color = 'orange') 

    ax1.set(xlabel ='Размеры гранул', ylabel = 'Количество гранул', 
            title ='Распределение размеров гранул сырья в обучающей выборке')


    ax2 = plt.subplot(1, 2, 2)
    ax1 = sns.histplot(train,  kde=True,bins=60,color = 'blue') 

    ax2.set(xlabel ='Размеры гранул', ylabel = 'Количество гранул',
            title ='Распределение размеров гранул сырья в тестовой выборке')
    plt.show()
    
    # расчет средних
    mean_train = train.mean()
    mean_test = test.mean()
    display(HTML(f"<font color='orange'>Средний размер гранул в обучающей выборке: {mean_train}</font>"))
    display(HTML(f"<font color='blue'>Средний размер гранул в тестовой выборке: {mean_test}</font>"))
    
    # расчет дисперсии
    var_train = np.var(train, ddof=1)
    var_test = np.var(test, ddof=1)
    display(HTML(f"<font color='orange'>Дисперсия размеров гранул в обучающей выборке: {var_train}</font>"))
    display(HTML(f"<font color='blue'>Дисперсия размеров гранул в тестовой выборке: {var_test}</font>"))
    
    # расчет стандартного отклонения
    std_train = np.sqrt(var_train)
    std_test = np.sqrt(var_test)
    display(HTML(
        f"<font color='orange'>Стандартное отклонение размеров гранул в обучающей выборке: \
        {std_train}</font>"))
    display(HTML(
        f"<font color='blue'>Стандартное отклонение размеров гранул в тестовой выборке: \
        {std_test}</font>"))
    
    # расчет межквартильного размаха 
    adv_train_min = mean_train - 3*std_train
    adv_train_max = 3*std_train + mean_train
    adv_test_min = mean_test - 3*std_test
    adv_test_max = 3*std_test + mean_test
    display(HTML(
        f"<font color='orange'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:\
        {adv_train_min} до {adv_train_max}</font>"))
    display(HTML(
        f"<font color='blue'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:\
        {adv_test_min} до {adv_test_max}</font>"))

# %%
compare_granules(gold_train['rougher.input.feed_size'],gold_test['rougher.input.feed_size'])
# Out:
# <font color='orange'>Средний размер гранул в обучающей выборке: 60.23985599255736</font>
# <font color='blue'>Средний размер гранул в тестовой выборке: 55.95275402889511</font>
# <font color='orange'>Дисперсия размеров гранул в обучающей выборке: 529.2442700162884</font>
# <font color='blue'>Дисперсия размеров гранул в тестовой выборке: 364.0591492476344</font>
# <font color='orange'>Стандартное отклонение размеров гранул в обучающей выборке:         23.005309604877922</font>
# <font color='blue'>Стандартное отклонение размеров гранул в тестовой выборке:         19.080334096855704</font>
# <font color='orange'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:        -8.776072822076408 до 129.25578480719113</font>
# <font color='blue'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:        -1.2882482616720026 до 113.19375631946221</font>

# %%
compare_granules(gold_train['primary_cleaner.input.feed_size'],gold_test['primary_cleaner.input.feed_size'])
# Out:
# <font color='orange'>Средний размер гранул в обучающей выборке: 7.322309906901298</font>
# <font color='blue'>Средний размер гранул в тестовой выборке: 7.266339191270909</font>
# <font color='orange'>Дисперсия размеров гранул в обучающей выборке: 0.3770724642469802</font>
# <font color='blue'>Дисперсия размеров гранул в тестовой выборке: 0.3723669484997233</font>
# <font color='orange'>Стандартное отклонение размеров гранул в обучающей выборке:         0.6140622641450786</font>
# <font color='blue'>Стандартное отклонение размеров гранул в тестовой выборке:         0.6102187710155459</font>
# <font color='orange'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:        5.480123114466062 до 9.164496699336533</font>
# <font color='blue'>Размеры большей части гранул в обучающей выборке колеблются в промежутке от:        5.435682878224271 до 9.096995504317547</font>

# %% [markdown]
# #### Вывод

# %% [markdown]
# *Различия в размерах гранул в обучаемой и тестовой выборках , подаваемых на вход на этапе флотации и первичной обработки минимальны. Данные различия не должны повлиять на оценку модели.*

# %% [markdown]
# ### Анализ суммарной концентрации всех веществ на разных стадиях очистки

# %%
gold_full_sum = gold_full.copy(deep=True)

# %%
gold_full_sum['raw_sum'] = gold_full_sum[['rougher.input.feed_au', 'rougher.input.feed_ag', 
                              'rougher.input.feed_pb', 'rougher.input.feed_sol']].sum(axis=1)
gold_full_sum['rougher_sum'] = gold_full_sum[['rougher.output.concentrate_au', 'rougher.output.concentrate_ag', 
                                            'rougher.output.concentrate_pb', 'rougher.output.concentrate_sol']].sum(axis=1)
gold_full_sum['primary_sum'] = gold_full_sum[['primary_cleaner.output.concentrate_au',
                                              'primary_cleaner.output.concentrate_ag', 'primary_cleaner.output.concentrate_pb',
                                              'primary_cleaner.output.concentrate_sol']].sum(axis=1)
gold_full_sum['final_sum'] = gold_full_sum[['final.output.concentrate_au', 
                                            'final.output.concentrate_ag', 'final.output.concentrate_pb', 
                                            'final.output.concentrate_sol']].sum(axis=1)
# Создадим выборки суммарной концентрации всех веществ на каждом этапе очистки.

# %%
gold = gold_full_sum[['raw_sum','rougher_sum','primary_sum','final_sum']]
gold.describe()
# Out:
#             raw_sum   rougher_sum   primary_sum     final_sum
# count  19439.000000  19439.000000  19439.000000  19439.000000
# mean      57.320789     68.170865     60.764731     68.653624
# std        7.212680     12.491279     10.017271      7.427536
# min        0.040000      0.000000      0.000000      0.000000
# 25%       53.557679     66.012495     58.929364     67.932362
# 50%       57.594391     70.181495     62.497674     69.598444
# 75%       61.953459     74.356904     65.667336     71.368472
# max       76.978947     88.140119     80.749343     80.210644

# %%
def gold_hist(df):
    plt.figure(figsize=(20,10))
    plt.title('Концентрация всех веществ на разных стадиях очистки', fontsize=20)
    plt.ylabel('Концентрация веществ', fontsize=15)
    plt.xticks(rotation=90)
    for column in df.columns:
        sns.histplot(data=df)
        
    plt.show()

# %%
gold_hist(gold)

# %% [markdown]
# *Коцентрация некоторых веществ на различных стадиях обработки равна нулю, ввиду их отсеивания на предыдущих стадиях. Во избежании влияния аномальных значений на дальнейший анализ, необходимо оптимизировать исследуемые данные.*

# %%
gold_clean = gold.query('(raw_sum != 0) & (rougher_sum != 0) & (primary_sum != 0) & (final_sum != 0)')

# %%
gold_clean.describe()
# Out:
#             raw_sum   rougher_sum   primary_sum     final_sum
# count  18848.000000  18848.000000  18848.000000  18848.000000
# mean      57.321500     69.585163     61.075460     69.011061
# std        7.173910      7.761554      8.886193      5.539257
# min        0.040000      0.040000      0.040000      0.040000
# 25%       53.525215     66.327918     59.006618     67.945265
# 50%       57.595439     70.314085     62.494760     69.600641
# 75%       61.962556     74.445415     65.636886     71.374700
# max       76.978947     88.140119     80.749343     80.210644

# %% [markdown]
# *Все же остались еще и близкие к нулю значения. Их необходимо тоже удалить, во избежании их влияния на дальнейший анализ.*

# %%
def counting_val(df):
    """Функция расчета количества значений меньше 1, в подаваемом в аргумент df"""
    count_nul = 0
    for col in df.columns:
        count_nul += len(df[df[col] < 1])
    return count_nul

# %%
counting_val(gold_clean)
# Out:
# 131

# %%
gold_clean = gold_clean.query('(raw_sum >= 1) & (rougher_sum >= 1) & (primary_sum >= 1) & (final_sum >= 1)')

# %%
gold_hist(gold_clean)

# %%
met_con(gold_clean, 'всех веществ')

# %%
substance_proportion(gold_clean,'всех веществ')

# %% [markdown]
# #### Вывод

# %% [markdown]
# *Проанализировав суммарную концентрацию веществ на различных этапах обработки, были обнаружены аномальные нулевые значения веществ (ввиду их отсеивания на предыдущих стадиях), влияющие на анализ. Данные аномалии были удалены, что так же необходимо выполнить и для обучающей и тестовых выборок.*

# %% [markdown]
# ### Удаление аномальных значений из обучающей и тестовой выборок

# %%
gold_full_sum = gold_full_sum.query('(raw_sum >= 1) & (rougher_sum >= 1) & (primary_sum >= 1) & (final_sum >= 1)')

# Удалим аномальные значения из исходных данных.

# %%
train_final = gold_train[gold_train.index.isin(gold_full_sum.index)]
test_final = gold_test[gold_test.index.isin(gold_full_sum.index)]

# Удалим аномалии из обучающей и тестовой выборок по индексам строк
# удаленных из исходных данных.

# %%
print(gold_full_sum.shape)
print(train_final.shape)
print(test_final.shape)
# Out:
# (18722, 76)
# (13599, 42)
# (5123, 42)

# %% [markdown]
# ### Вывод

# %% [markdown]
# *Был проведен анализ изменения концентрации металлов на всех этапах обработки.*
# * *доля золота увеличилась на 34%*
# * *доля серебра уменьшилась на 10%*
# * *доля свинца увеличилась на 21%*
#
# *Распределение размеров гранул на обучающей и тестовой выборках практически идентично и не влияет на оценку модели.*
# *При проведении анализа суммарной концентрации металлов на различных этапах, были обнаружены аномальные значения, влияющие на итоговые результаты. Данные аномалии были удалены из всех данных.*

# %% [markdown]
# ## Модель

# %% [markdown]
# ### Метрика качества

# %% [markdown]
# *Метрика качества, необходимая для оценки эффективности процесса очистки золотосодержащей руды — sMAPE (симметричное среднее абсолютное процентное отклонение).
# Метрика sMAPE вычисляется так:*
#
#
# $$sMAPE = \frac{1}{N} \sum_{i=1}^{N}\frac{\left | y_{i} -\
# \hat{y}_{i}\right |}{\left ( \left | y_{i} \right | +\left | \hat{y}_{i} \right |\right )/2} *100\%$$
#
# *Значение целевого признака для объекта с порядковым номером i в выборке, на которой измеряется качество:* $$y_{i}$$
# *Значение предсказания для объекта с порядковым номером i, например, в тестовой выборке:* $$\hat{y}_{i}$$
# *Количество объектов в выборке:* $$N$$
# *Суммирование по всем объектам выборки (i меняется от 1 до N).* $$\sum_{i=1}^{N}$$

# %%
def smape_calc(target,prediction):
    """Функция вычисления метрики smape"""
    diff = abs(target - prediction)
    add = (abs(target) + abs(prediction))/2
    smape_stage = 1/len(target)*sum(diff/add)*100
    
    return smape_stage

# %%
def final_smape(smape_r,smape_f):
    """Функция вычисления итоговой метрики smape"""
    final_smape = 0.25*smape_r + 0.75*smape_f
    return final_smape

# %%
features_train = train_final.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_rougher_train = train_final['rougher.output.recovery']
target_final_train = train_final['final.output.recovery']


    
features_test = test_final.drop(['rougher.output.recovery','final.output.recovery'], axis=1)
target_rougher_test = test_final['rougher.output.recovery']
target_final_test = test_final['final.output.recovery']

# %%
features_train.reset_index(drop=True,inplace=True)
target_rougher_train.reset_index(drop=True,inplace=True)
target_final_train.reset_index(drop=True,inplace=True)

features_test.reset_index(drop=True,inplace=True)
target_rougher_test.reset_index(drop=True,inplace=True)
target_final_test.reset_index(drop=True,inplace=True)

# %%
scaler = StandardScaler()
scaler.fit(features_train)
features_train = scaler.transform(features_train)
features_test = scaler.transform(features_test)

# %% [markdown]
# ### Расчет метрики качества для выбранных моделей

# %%
score = make_scorer(smape_calc, greater_is_better=False)

# %%
model_lr = LinearRegression()

# %%
tree_params = {'max_depth': range(1,16,1)}
tree_model = DecisionTreeRegressor(random_state=12345)

forest_params = {'max_depth': range(8,13,1),'n_estimators': range(135,139,1)}
forest_model = RandomForestRegressor(random_state=12345)
# окончательный диапазон параметров выставлен после подбора RandomizedSearchCV и GridSearchCV

# %% [markdown]
# ### LinearRegression

# %%
# %%time
cv_sc_lin_rougher = cross_val_score(LinearRegression(),
                                          features_train,
                                          target_rougher_train,
                                          cv=5, scoring=score).mean()
cv_sc_lin_final = cross_val_score(LinearRegression(),
                                        features_train,
                                        target_final_train,
                                        cv=5, scoring=score).mean()
smape_lin = final_smape(cv_sc_lin_rougher,cv_sc_lin_final)

display(HTML(f"<font color='blue'>Итоговое симметричное среднее абсолютное процентное отклонение: {smape_lin:.3f}%</font>"))
# Out:
# <font color='blue'>Итоговое симметричное среднее абсолютное процентное отклонение: -10.014%</font>
# Wall time: 183 ms

# %% [markdown]
# ### Поиск оптимальных параметров для моделей случайного дерева и решающего леса

# %%
def random_grid(model,params,scoring,features,target):
    """Функция осуществляет грубый подбор параметров, сужая их поиск, из диапазона переданного в аргумент, 
    для принимаемой в аргумент модели"""
    model_random = RandomizedSearchCV(model,params,cv=5, n_jobs=-1,scoring=score)
    model_random.fit(features,target)
    best_params_random = model_random.best_params_
    best_score_random = model_random.best_score_
    return model_random,best_params_random,best_score_random

# %%
# %%time
random_grid(tree_model,tree_params,score,features_train,target_rougher_train)
# Out:
# Wall time: 4.63 s
# (RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=12345),
#                     n_jobs=-1, param_distributions={'max_depth': range(1, 16)},
#                     scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 4},
#  -6.900283249926041)

# %%
# %%time
random_grid(tree_model,tree_params,score,features_train,target_final_train)
# Out:
# Wall time: 2.44 s
# (RandomizedSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=12345),
#                     n_jobs=-1, param_distributions={'max_depth': range(1, 16)},
#                     scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 2},
#  -9.221328412135156)

# %%
# %%time
random_grid(forest_model,forest_params,score,features_train,target_rougher_train)
# Out:
# Wall time: 9min 40s
# (RandomizedSearchCV(cv=10, estimator=RandomForestRegressor(random_state=12345),
#                     n_jobs=-1,
#                     param_distributions={'max_depth': range(11, 14),
#                                          'n_estimators': range(130, 139, 2)},
#                     scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'n_estimators': 132, 'max_depth': 11},
#  -6.293731841971323)

# %%
# %%time
random_grid(forest_model,forest_params,score,features_train,target_final_train)
# Out:
# Wall time: 3min 59s
# (RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(random_state=12345),
#                     n_jobs=-1,
#                     param_distributions={'max_depth': range(8, 13),
#                                          'n_estimators': range(135, 139)},
#                     scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'n_estimators': 137, 'max_depth': 8},
#  -9.112008983273922)

# %%
def params_grid(model,params,scoring,features,target):
    """Функция ищет лучшие параметры из диапазона переданного в аргумент, 
    для принимаемой в аргумент модели"""
    model_grid = GridSearchCV(model,params,cv=5, n_jobs=-1,scoring=score)
    model_grid.fit(features,target)
    best_params = model_grid.best_params_
    best_score = model_grid.best_score_
    return model_grid,best_params,best_score
# Out:
# Wall time: 0 ns

# %%
# %%time
params_grid(tree_model,tree_params,score,features_train,target_rougher_train)
# Out:
# Wall time: 3.55 s
# (GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=12345),
#               n_jobs=-1, param_grid={'max_depth': range(1, 16)},
#               scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 3},
#  -6.809826289649573)

# %%
# %%time
params_grid(tree_model,tree_params,score,features_train,target_final_train)
# Out:
# Wall time: 3.68 s
# (GridSearchCV(cv=5, estimator=DecisionTreeRegressor(random_state=12345),
#               n_jobs=-1, param_grid={'max_depth': range(1, 16)},
#               scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 2},
#  -9.221328412135156)

# %%
# %%time
params_grid(forest_model,forest_params,score,features_train,target_rougher_train)
# Out:
# Wall time: 13min 33s
# (GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=12345),
#               n_jobs=-1,
#               param_grid={'max_depth': range(8, 12),
#                           'n_estimators': range(130, 140)},
#               scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 9, 'n_estimators': 137},
#  -6.377255445029743)

# %%
# %%time
params_grid(forest_model,forest_params,score,features_train,target_final_train)
# Out:
# Wall time: 8min 13s
# (GridSearchCV(cv=5, estimator=RandomForestRegressor(random_state=12345),
#               n_jobs=-1,
#               param_grid={'max_depth': range(8, 13),
#                           'n_estimators': range(135, 139)},
#               scoring=make_scorer(smape_calc, greater_is_better=False)),
#  {'max_depth': 8, 'n_estimators': 137},
#  -9.112008983273922)

# %% [markdown]
# ### DecisionTreeRegressor

# %%
# %%time
cv_sc_tree_rougher = cross_val_score(DecisionTreeRegressor(random_state=12345, max_depth=3),
                                          features_train,
                                          target_rougher_train,
                                          cv=5, scoring=score).mean()
cv_sc_tree_final = cross_val_score(DecisionTreeRegressor(random_state=12345, max_depth=2),
                                        features_train,
                                        target_final_train,
                                        cv=5, scoring=score).mean()
smape_tree = final_smape(cv_sc_tree_rougher,cv_sc_tree_final)

display(HTML(f"<font color='blue'>Итоговое симметричное среднее абсолютное процентное \
     отклонение: {smape_tree:.3f}%</font>"))
# Out:
# <font color='blue'>Итоговое симметричное среднее абсолютное процентное      отклонение: -8.618%</font>
# Wall time: 861 ms

# %% [markdown]
# ### RandomForestRegressor

# %%
# %%time
cv_sc_forest_rougher = cross_val_score(RandomForestRegressor(random_state=12345,max_depth=9, n_estimators=137),
                                          features_train,
                                          target_rougher_train,
                                          cv=5, scoring=score).mean()
cv_sc_forest_final = cross_val_score(RandomForestRegressor(random_state=12345,max_depth=8, n_estimators=137),
                                        features_train,
                                        target_final_train,
                                        cv=5, scoring=score).mean()
smape_forest = final_smape(cv_sc_forest_rougher,cv_sc_forest_final)

display(HTML(f"<font color='blue'>Итоговое симметричное среднее абсолютное процентное \
     отклонение: {smape_forest:.3f}%</font>"))
# Out:
# Wall time: 7min 47s
# -8.320052249953307

# %% [markdown]
# #### Вывод

# %% [markdown]
# *Лучший результат показывает модель Случайного леса. Обучим ее для проверки на тестовой выборке.*

# %% [markdown]
# ### Проверка лучшей модели на тестовой выборке

# %%
# %%time
best_model_r = RandomForestRegressor(random_state=12345, max_depth=9, n_estimators=137)
best_model_r.fit(features_train,target_rougher_train)
prediction_rougher = best_model_r.predict(features_test)
smape_roug = smape_calc(target_rougher_test,prediction_rougher)

best_model_f = RandomForestRegressor(random_state=12345, max_depth=8, n_estimators=137)
best_model_f.fit(features_train,target_final_train)
prediction_final = best_model_f.predict(features_test)
smape_fin = smape_calc(target_final_test,prediction_final)

smape_final = final_smape(smape_roug,smape_fin)

display(HTML(f"<font color='blue'>Итоговое симметричное среднее абсолютное процентное \
     отклонение: {smape_final:.3f}%</font>"))
# Out:
# <font color='blue'>Итоговое симметричное среднее абсолютное процентное      отклонение: 6.848%</font>
# CPU times: user 1min 4s, sys: 29.8 ms, total: 1min 4s
# Wall time: 1min 5s

# %% [markdown]
# ### Проверка на адекватность

# %% [markdown]
# *Для проверки выбранной модели на адекватность, выбрана модель `DummyRegressor` библиотеки `Sklearn`.
# Этот классификатор служит простой базой для сравнения с другими более сложными классификаторами.
# Конкретное поведение базовой линии выбирается с помощью параметра `strategy`.*
# - *`mean`, всегда предсказывает среднее значение тренировочного набора*

# %%
# %%time
dummy_uniform = DummyRegressor(strategy='mean').fit(features_train, target_rougher_train)
dummy_rog = dummy_uniform.predict(features_test)
smape_dummy_roug = smape_calc(target_rougher_test,dummy_rog)

dummy_uniform_1 = DummyRegressor(strategy='mean').fit(features_train, target_final_train)
dummy_fin = dummy_uniform_1.predict(features_test)
smape_dummy_fin = smape_calc(target_final_test,dummy_fin)

smape_dummy = final_smape(smape_dummy_roug,smape_dummy_fin)

display(HTML(f"<font color='blue'>Итоговое симметричное среднее абсолютное процентное \
     отклонение: {smape_dummy:.3f}%</font>"))
# Out:
# <font color='blue'>Итоговое симметричное среднее абсолютное процентное      отклонение: 7.779%</font>
# CPU times: user 10 ms, sys: 10 µs, total: 10 ms
# Wall time: 58.6 ms

# %% [markdown]
# *Итоговое симметричное среднее абсолютное процентное отклонение "иммитации случайной модели": 7.779%.
# Итоговое симметричное среднее абсолютное процентное отклонение, выбранной модели Случайного леса: 6.848%,
# что естественно ниже.
# Следует считать, что выбранная модель справляется гораздо лучше случайной.*

# %% [markdown]
# ### Вывод

# %% [markdown]
# *Заказчиком были предоставлены сырые данные: их просто выгрузили из хранилища.*
# * *Была проведена предобработка данных:*
#  - *определились с целевыми признаками и признаками, необходимыми для их оценки;*
#  - *удалены лишние признаки;*
#  - *заполнены пропуски.*
# * *Проведен анализ:*
#  - *Анализ концентрации металлов на различных этапах выявил прирост концентрации золота в 34%*
#  - *Проведеное сравнение размеров гранул сырья в обучаемой и тестовой выборках, показало их идентичность*
#  - *На этапе анализа суммарной концентрации всех веществ были выявлены и удалены аномальные значения*
# * *На этапе построения модели:*
#  - *Выведена метрика качества sMAPE*
#  - *Осуществлен выбор наиболее подходящей модели для оценки эффективной работы промышленных предприятий*
#  - *Наилучшая модель проверена на тестовой выборке*
#  - *Модель прошла проверку на адекватность, сравнением со "случайно" предсказывающей моделью*
#
#  *Подготовлен прототип модели машинного обучения для «Цифры», предсказывающий коэффициент восстановления золота из золотосодержащей руды.*
